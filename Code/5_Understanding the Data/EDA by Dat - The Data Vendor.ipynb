# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import cufflinks as cf

import plotly.offline as py 
import plotly.figure_factory as ff 
import plotly.graph_objs as go 

from plotly import tools 


#To plot figs on jupyter
# %matplotlib inline
# figure size in inches
rcParams['figure.figsize'] = 16,8

# %% [markdown]
# # Importing the Dataset

# %%
df_loan = pd.read_csv("loan.csv",encoding='utf-8',header=0)
# Out:
# C:\Users\Siddhi\Anaconda3\envs\Latest_Env\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning:
#
# Columns (19,55) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
# Looking at the Data

df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           887379 non-null  int64
#  1   member_id                    887379 non-null  int64
#  2   loan_amnt                    887379 non-null  float64
#  3   funded_amnt                  887379 non-null  float64
#  4   funded_amnt_inv              887379 non-null  float64
#  5   term                         887379 non-null  object
#  6   int_rate                     887379 non-null  float64
#  7   installment                  887379 non-null  float64
#  8   grade                        887379 non-null  object
#  9   sub_grade                    887379 non-null  object
#  10  emp_title                    835917 non-null  object
#  11  emp_length                   842554 non-null  object
#  12  home_ownership               887379 non-null  object
#  13  annual_inc                   887375 non-null  float64
#  14  verification_status          887379 non-null  object
#  15  issue_d                      887379 non-null  object
#  16  loan_status                  887379 non-null  object
#  17  pymnt_plan                   887379 non-null  object
#  18  url                          887379 non-null  object
#  19  desc                         126028 non-null  object
#  20  purpose                      887379 non-null  object
#  21  title                        887227 non-null  object
#  22  zip_code                     887379 non-null  object
#  23  addr_state                   887379 non-null  object
#  24  dti                          887379 non-null  float64
#  25  delinq_2yrs                  887350 non-null  float64
#  26  earliest_cr_line             887350 non-null  object
#  27  inq_last_6mths               887350 non-null  float64
#  28  mths_since_last_delinq       433067 non-null  float64
#  29  mths_since_last_record       137053 non-null  float64
#  30  open_acc                     887350 non-null  float64
#  31  pub_rec                      887350 non-null  float64
#  32  revol_bal                    887379 non-null  float64
#  33  revol_util                   886877 non-null  float64
#  34  total_acc                    887350 non-null  float64
#  35  initial_list_status          887379 non-null  object
#  36  out_prncp                    887379 non-null  float64
#  37  out_prncp_inv                887379 non-null  float64
#  38  total_pymnt                  887379 non-null  float64
#  39  total_pymnt_inv              887379 non-null  float64
#  40  total_rec_prncp              887379 non-null  float64
#  41  total_rec_int                887379 non-null  float64
#  42  total_rec_late_fee           887379 non-null  float64
#  43  recoveries                   887379 non-null  float64
#  44  collection_recovery_fee      887379 non-null  float64
#  45  last_pymnt_d                 869720 non-null  object
#  46  last_pymnt_amnt              887379 non-null  float64
#  47  next_pymnt_d                 634408 non-null  object
#  48  last_credit_pull_d           887326 non-null  object
#  49  collections_12_mths_ex_med   887234 non-null  float64
#  50  mths_since_last_major_derog  221703 non-null  float64
#  51  policy_code                  887379 non-null  float64
#  52  application_type             887379 non-null  object
#  53  annual_inc_joint             511 non-null     float64
#  54  dti_joint                    509 non-null     float64
#  55  verification_status_joint    511 non-null     object
#  56  acc_now_delinq               887350 non-null  float64
#  57  tot_coll_amt                 817103 non-null  float64
#  58  tot_cur_bal                  817103 non-null  float64
#  59  open_acc_6m                  21372 non-null   float64
#  60  open_il_6m                   21372 non-null   float64
#  61  open_il_12m                  21372 non-null   float64
#  62  open_il_24m                  21372 non-null   float64
#  63  mths_since_rcnt_il           20810 non-null   float64
#  64  total_bal_il                 21372 non-null   float64
#  65  il_util                      18617 non-null   float64
#  66  open_rv_12m                  21372 non-null   float64
#  67  open_rv_24m                  21372 non-null   float64
#  68  max_bal_bc                   21372 non-null   float64
#  69  all_util                     21372 non-null   float64
#  70  total_rev_hi_lim             817103 non-null  float64
#  71  inq_fi                       21372 non-null   float64
#  72  total_cu_tl                  21372 non-null   float64
#  73  inq_last_12m                 21372 non-null   float64
# dtypes: float64(49), int64(2), object(23)
# memory usage: 501.0+ MB

# %%
# Column Names

print(df_loan.columns)
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl',
#        'inq_last_12m'],
#       dtype='object')

# %%
# Unique Values

print(df_loan.shape)
print(df_loan.isnull().sum().value_counts())
# Out:
# (887379, 74)
# 0         34
# 866007    12
# 29         7
# 70276      3
# 886868     2
# 152        1
# 4          1
# 502        1
# 51462      1
# 761351     1
# 866569     1
# 145        1
# 44825      1
# 886870     1
# 868762     1
# 750326     1
# 454312     1
# 252971     1
# 53         1
# 665676     1
# 17659      1
# dtype: int64

# %% [markdown]
# # Distribution of Loan Amount

# %%
#I will start looking the loan_amnt column
plt.figure(figsize=(12,6))

plt.subplot(121)
g = sns.distplot(df_loan["loan_amnt"])
g.set_xlabel("", fontsize=12)
g.set_ylabel("Frequency Dist", fontsize=12)
g.set_title("Frequency Distribuition", fontsize=20)

plt.subplot(122)
g1 = sns.violinplot(y="loan_amnt", data=df_loan, 
               inner="quartile", palette="hls")
g1.set_xlabel("", fontsize=12)
g1.set_ylabel("Amount Dist", fontsize=12)
g1.set_title("Amount Distribuition", fontsize=20)

plt.show()

# %% [markdown]
# # Distribution of Interest Rate

# %%
df_loan['int_round'] = df_loan['int_rate'].round(0).astype(int)

plt.figure(figsize = (10,8))

#Exploring the Int_rate
plt.subplot(211)
g = sns.distplot(np.log(df_loan["int_rate"]))
g.set_xlabel("", fontsize=12)
g.set_ylabel("Distribuition", fontsize=12)
g.set_title("Int Rate Log distribuition", fontsize=20)

plt.subplot(212)
g1 = sns.countplot(x="int_round",data=df_loan, 
                   palette="Set2")
g1.set_xlabel("Int Rate", fontsize=12)
g1.set_ylabel("Count", fontsize=12)
g1.set_title("Int Rate Normal Distribuition", fontsize=20)

plt.subplots_adjust(wspace = 0.2, hspace = 0.6,top = 0.9)

plt.show()

# %% [markdown]
# # Distribution of Loan Status

# %%
df_loan.loc[df_loan.loan_status == \
            'Does not meet the credit policy. Status:Fully Paid', 'loan_status'] = 'NMCP Fully Paid'
df_loan.loc[df_loan.loan_status == \
            'Does not meet the credit policy. Status:Charged Off', 'loan_status'] = 'NMCP Charged Off'

# %%
print(df_loan.loan_status.value_counts())

plt.figure(figsize = (12,14))

plt.subplot(311)
g = sns.countplot(x="loan_status", data=df_loan)
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("", fontsize=12)
g.set_ylabel("Count", fontsize=15)
g.set_title("Loan Status Count", fontsize=20)

plt.subplot(312)
g1 = sns.boxplot(x="loan_status", y="total_acc", data=df_loan)
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)
g1.set_xlabel("", fontsize=12)
g1.set_ylabel("Total Acc", fontsize=15)
g1.set_title("Duration Count", fontsize=20)

plt.subplot(313)
g2 = sns.violinplot(x="loan_status", y="loan_amnt", data=df_loan)
g2.set_xticklabels(g2.get_xticklabels(),rotation=45)
g2.set_xlabel("Duration Distribuition", fontsize=15)
g2.set_ylabel("Count", fontsize=15)
g2.set_title("Loan Amount", fontsize=20)

plt.subplots_adjust(wspace = 0.2, hspace = 0.7,top = 0.9)

plt.show()
# Out:
# Current               601779
# Fully Paid            207723
# Charged Off            45248
# Late (31-120 days)     11591
# Issued                  8460
# In Grace Period         6253
# Late (16-30 days)       2357
# NMCP Fully Paid         1988
# Default                 1219
# NMCP Charged Off         761
# Name: loan_status, dtype: int64

# %% [markdown]
# # Distribution of Issue Date

# %%
df_loan['issue_month'], df_loan['issue_year'] = df_loan['issue_d'].str.split('-', 1).str
# Out:
# C:\Users\Siddhi\Anaconda3\envs\Latest_Env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
# Columnar iteration over characters will be deprecated in future releases.

# %%
months_order = ["Jan", "Feb", "Mar", "Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
df_loan['issue_month'] = pd.Categorical(df_loan['issue_month'],categories=months_order, ordered=True)

#Issue_d x loan_amount
plt.figure(figsize = (14,6))

g = sns.pointplot(x='issue_month', y='loan_amnt', 
                  data=df_loan, 
                  hue='loan_status')
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_xlabel("Duration Distribuition", fontsize=15)
g.set_ylabel("Mean amount", fontsize=15)
g.legend(loc='best')
g.set_title("Loan Amount by Months", fontsize=20)
plt.show()

# %%
# Analysing Loan by Years

plt.figure(figsize = (14,6))
#Looking the count of defaults though the issue_d that is The month which the loan was funded
g = sns.countplot(x='issue_year', data=df_loan,
                  hue='loan_status')
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_xlabel("Dates", fontsize=15)
g.set_ylabel("Count", fontsize=15)
g.legend(loc='upper left')
g.set_title("Analysing Loan Status by Years", fontsize=20)
plt.show()

# %%
plt.figure(figsize = (14,6))
#Looking the count of defaults though the issue_d that is The month which the loan was funded
g = sns.countplot(x='issue_year', data=df_loan[df_loan['loan_status'] =='Default'])
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_xlabel("Dates", fontsize=15)
g.set_ylabel("Count", fontsize=15)
g.legend(loc='upper left')
g.set_title("Analysing Defaults Count by Time", fontsize=20)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Lets Generate a Crosstab using Heatmap

# %%
#Exploring the loan_status x purpose
purp_loan= ['purpose', 'loan_status']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_loan[purp_loan[0]], df_loan[purp_loan[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col2 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col3 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col4 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col5 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col6 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col7 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col8 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row0_col9 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col0 {
#             background-color:  #a5dba5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col1 {
#             background-color:  #85ca85;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col2 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col3 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col4 {
#             background-color:  #a4dba4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col5 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col6 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col7 {
#             background-color:  #a5dba5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col8 {
#             background-color:  #b0e2b0;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row1_col9 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col8 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row2_col9 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col8 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row3_col9 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col0 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col1 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col2 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col3 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col4 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col5 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col6 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col7 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col8 {
#             background-color:  #afe1af;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row4_col9 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col0 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col3 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col4 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col6 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col7 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col8 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_93a79ef0_7c89_11ea_aed6_0cdd2411a5e3row5_col9 {
#             background-color:  #ddfbdd;
#             color:  #000000;

# %%
loan_grade = ['loan_status', 'grade']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_loan[loan_grade[0]], df_loan[loan_grade[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row0_col0 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row0_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row0_col2 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row0_col3 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row0_col4 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row0_col5 {
#             background-color:  #b5e4b5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row0_col6 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row1_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row1_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row1_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row1_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row2_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row3_col0 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row3_col1 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row3_col2 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row3_col3 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row3_col4 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row3_col5 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row3_col6 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row4_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row4_col3 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row4_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row4_col5 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row4_col6 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row5_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row5_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row5_col2 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row5_col3 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row5_col4 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row5_col5 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row5_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row6_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row6_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row6_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row6_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row7_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row7_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row7_col3 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row7_col4 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row7_col5 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row7_col6 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row8_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_953120cc_7c89_11ea_ae6a_0cdd2411a5e3row8_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;

# %%
loan_home = ['loan_status', 'home_ownership']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_loan[loan_home[0]], df_loan[loan_home[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row0_col1 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row0_col2 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row0_col3 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row0_col4 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row0_col5 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row1_col2 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row1_col3 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row1_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row1_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row3_col0 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row3_col1 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row3_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row3_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row3_col4 {
#             background-color:  #a4dba4;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row3_col5 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row4_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row4_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row4_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row4_col4 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row4_col5 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row5_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row5_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row5_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row5_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row5_col5 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row6_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row6_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row6_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row7_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row7_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row7_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row7_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row7_col5 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row8_col2 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row8_col3 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row8_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row8_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row9_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row9_col2 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row9_col3 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row9_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_98ddbf6c_7c89_11ea_a1c3_0cdd2411a5e3row9_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;

# %%
#Looking the 'verification_status' column that is the Indicates 
#if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified
loan_verification = ['loan_status', 'verification_status']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_loan[loan_verification[0]], df_loan[loan_verification[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row0_col0 {
#             background-color:  #d6f7d6;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row0_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row0_col2 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row3_col0 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row3_col1 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row3_col2 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row4_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row4_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row5_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row5_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row5_col2 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row7_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row7_col1 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row7_col2 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row8_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row9_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row9_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3" ><thead>    <tr>        <th class="index_name level0" >verification_status</th>        <th class="col_heading level0 col0" >Not Verified</th>        <th class="col_heading level0 col1" >Source Verified</th>        <th class="col_heading level0 col2" >Verified</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3level0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row0_col0" class="data row0 col0" >12208</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row0_col1" class="data row0 col1" >13740</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row0_col2" class="data row0 col2" >19300</td>
#             </tr>
#             <tr>
#                         <th id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3level0_row1" class="row_heading level0 row1" >Current</th>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row1_col0" class="data row1 col0" >171400</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row1_col1" class="data row1 col1" >243705</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row1_col2" class="data row1 col2" >186674</td>
#             </tr>
#             <tr>
#                         <th id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3level0_row2" class="row_heading level0 row2" >Default</th>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row2_col0" class="data row2 col0" >278</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row2_col1" class="data row2 col1" >462</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row2_col2" class="data row2 col2" >479</td>
#             </tr>
#             <tr>
#                         <th id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3level0_row3" class="row_heading level0 row3" >Fully Paid</th>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row3_col0" class="data row3 col0" >73856</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row3_col1" class="data row3 col1" >60271</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row3_col2" class="data row3 col2" >73596</td>
#             </tr>
#             <tr>
#                         <th id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3level0_row4" class="row_heading level0 row4" >In Grace Period</th>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row4_col0" class="data row4 col0" >1403</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row4_col1" class="data row4 col1" >2523</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row4_col2" class="data row4 col2" >2327</td>
#             </tr>
#             <tr>
#                         <th id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3level0_row5" class="row_heading level0 row5" >Issued</th>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row5_col0" class="data row5 col0" >2779</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row5_col1" class="data row5 col1" >2836</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row5_col2" class="data row5 col2" >2845</td>
#             </tr>
#             <tr>
#                         <th id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3level0_row6" class="row_heading level0 row6" >Late (16-30 days)</th>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row6_col0" class="data row6 col0" >473</td>
#                         <td id="T_9bf5e67a_7c89_11ea_8863_0cdd2411a5e3row6_col1" class="data row6 col1" >1006</td>

# %% [markdown]
# # Understanding the Installment Column

# %%
sns.distplot(df_loan['installment'])
plt.show()

# %% [markdown]
# # Lookin up Home Ownership by Loan Amount

# %%
plt.figure(figsize = (10,6))

g = sns.violinplot(x="home_ownership",y="loan_amnt",data=df_loan,
               kind="violin",
               split=True,palette="hls",
               hue="application_type")
g.set_title("Homer Ownership - Loan Distribuition", fontsize=20)
g.set_xlabel("", fontsize=15)
g.set_ylabel("Loan Amount", fontsize=15)

plt.show()

# %% [markdown]
# # Distribution of Purpose

# %%
# Now will start exploring the Purpose variable
print("Purposes count description: ")
print(pd.crosstab(df_loan.purpose, df_loan.application_type))

plt.figure(figsize = (12,8))

plt.subplot(211)
g = sns.countplot(x="purpose",data=df_loan,
                  palette='hls')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_title("Application Type - Loan Amount", fontsize=20)
g.set_xlabel("", fontsize=15)
g.set_ylabel("Loan Amount", fontsize=15)

plt.subplot(212)
g1 = sns.violinplot(x="purpose",y="loan_amnt",data=df_loan,
               hue="application_type", split=True)
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)
g1.set_title("Application Type - Loan Amount", fontsize=20)
g1.set_xlabel("", fontsize=15)
g1.set_ylabel("Loan Amount", fontsize=15)

plt.subplots_adjust(wspace = 0.2, hspace = 0.8,top = 0.9)
plt.show()
# Out:
# Purposes count description:
# application_type    INDIVIDUAL  JOINT
# purpose
# car                       8862      1
# credit_card             206067    115
# debt_consolidation      523881    334
# educational                423      0
# home_improvement         51803     26
# house                     3707      0
# major_purchase           17275      2
# medical                   8538      2
# moving                    5413      1
# other                    42867     27
# renewable_energy           575      0
# small_business           10375      2
# vacation                  4735      1
# wedding                   2347      0

# %% [markdown]
# # Looking at Grades

# %%
fig, ax = plt.subplots(2,1, figsize=(24,10))
sns.boxplot(x="grade", y="loan_amnt", data=df_loan,
            palette="hls",ax=ax[0], hue="application_type", 
            order=["A",'B','C','D','E','F', 'G'])

sns.lvplot(x="sub_grade", y="loan_amnt",data=df_loan, 
               palette="hls", ax=ax[1])

plt.show()
# Out:
# C:\Users\Siddhi\Anaconda3\envs\Latest_Env\lib\site-packages\seaborn\categorical.py:2619: UserWarning:
#
# The `lvplot` function has been renamed to `boxenplot`. The original name will be removed in a future release. Please update your code.

# %% [markdown]
# # Heatmap of Address State vs Loan Status

# %%
#Exploring the State Adress x Loan Status
adress_loan = ['addr_state', 'loan_status']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_loan[adress_loan[0]], df_loan[adress_loan[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col1 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col3 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col5 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col6 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col7 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col8 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row0_col9 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col0 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col1 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col2 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col3 {
#             background-color:  #d6f7d6;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col4 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col5 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col6 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col7 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col8 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row1_col9 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col0 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col2 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col3 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col4 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col5 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col6 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col7 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col8 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row2_col9 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col0 {
#             background-color:  #c5edc5;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col1 {
#             background-color:  #c0eac0;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col2 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col3 {
#             background-color:  #c6eec6;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col4 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col5 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col6 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col7 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col8 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row3_col9 {
#             background-color:  #c4edc4;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col8 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row4_col9 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col0 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col1 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col2 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col3 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col4 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col5 {
#             background-color:  #c4edc4;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col6 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col7 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col8 {
#             background-color:  #c9efc9;
#             color:  #000000;
#         }    #T_bd499fbe_7c89_11ea_a183_0cdd2411a5e3row5_col9 {
#             background-color:  #b0e2b0;
#             color:  #000000;

# %% [markdown]
# # Looking at The Missing Values

# %%
null_perc = df_loan.isnull().sum()/df_loan.isnull().count()

plt.figure(figsize=(15,5))

sns.barplot(x = np.arange(len(null_perc)), y =null_perc, palette="magma")

plt.xticks(np.arange(len(null_perc)),null_perc.index,rotation=90)
plt.ylabel('% missing data')
# Out:
# Text(0, 0.5, '% missing data')

# %% [markdown]
# # Correlation

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Compute the correlation matrix
corr = df_loan.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
